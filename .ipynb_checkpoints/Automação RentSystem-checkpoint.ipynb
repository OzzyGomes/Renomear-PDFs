# %%
import sys

! {sys.executable} -m pip install textract
# Out:
# Collecting textract
#   Downloading textract-1.6.4.tar.gz (17 kB)
# Collecting argcomplete~=1.10.0
#   Downloading argcomplete-1.10.3-py2.py3-none-any.whl (36 kB)
# Collecting beautifulsoup4~=4.8.0
#   Downloading beautifulsoup4-4.8.2-py3-none-any.whl (106 kB)
# Collecting chardet==3.*
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting docx2txt~=0.8
#   Downloading docx2txt-0.8.tar.gz (2.8 kB)
# Collecting EbookLib==0.*
#   Downloading EbookLib-0.17.1.tar.gz (111 kB)
# Collecting extract-msg<=0.29.*
#   Downloading extract_msg-0.28.7-py2.py3-none-any.whl (69 kB)
# Collecting pdfminer.six==20191110
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
#   Downloading pdfminer.six-20191110-py2.py3-none-any.whl (5.6 MB)
# Collecting python-pptx~=0.6.18
#   Downloading python-pptx-0.6.21.tar.gz (10.1 MB)
# Collecting six~=1.12.0
#   Downloading six-1.12.0-py2.py3-none-any.whl (10 kB)
# Collecting SpeechRecognition~=3.8.1
#   Downloading SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8 MB)
# Collecting xlrd~=1.2.0
#   Downloading xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
# Requirement already satisfied: lxml in c:\users\ojgomes\anaconda3\lib\site-packages (from EbookLib==0.*->textract) (4.6.3)
# Requirement already satisfied: sortedcontainers in c:\users\ojgomes\anaconda3\lib\site-packages (from pdfminer.six==20191110->textract) (2.4.0)
# Collecting pycryptodome
#   Downloading pycryptodome-3.14.1-cp35-abi3-win_amd64.whl (1.8 MB)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\ojgomes\anaconda3\lib\site-packages (from beautifulsoup4~=4.8.0->textract) (2.2.1)
# Collecting imapclient==2.1.0
#   Downloading IMAPClient-2.1.0-py2.py3-none-any.whl (73 kB)
# Collecting compressed-rtf>=1.0.6
#   Downloading compressed_rtf-1.0.6.tar.gz (5.8 kB)
# Collecting tzlocal>=2.1
#   Downloading tzlocal-4.1-py3-none-any.whl (19 kB)
# Collecting ebcdic>=1.1.1
#   Downloading ebcdic-1.1.1-py2.py3-none-any.whl (128 kB)
# Requirement already satisfied: olefile>=0.46 in c:\users\ojgomes\anaconda3\lib\site-packages (from extract-msg<=0.29.*->textract) (0.46)
# Requirement already satisfied: Pillow>=3.3.2 in c:\users\ojgomes\anaconda3\lib\site-packages (from python-pptx~=0.6.18->textract) (8.4.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in c:\users\ojgomes\anaconda3\lib\site-packages (from python-pptx~=0.6.18->textract) (3.0.1)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Collecting tzdata
#   Downloading tzdata-2021.5-py2.py3-none-any.whl (339 kB)
# Building wheels for collected packages: textract, EbookLib, docx2txt, compressed-rtf, python-pptx
#   Building wheel for textract (setup.py): started
#   Building wheel for textract (setup.py): finished with status 'done'
#   Created wheel for textract: filename=textract-1.6.4-py3-none-any.whl size=22888 sha256=4d66eb8b475f58b33176b753d177b66f8672e5d745dabe1bc4c138d5d5208b94
#   Stored in directory: c:\users\ojgomes\appdata\local\pip\cache\wheels\31\50\c6\acfae9490f182344f3a7a4561ddac71bc59903ed7d56f07a6c
#   Building wheel for EbookLib (setup.py): started
#   Building wheel for EbookLib (setup.py): finished with status 'done'
#   Created wheel for EbookLib: filename=EbookLib-0.17.1-py3-none-any.whl size=38183 sha256=b6b804a93f4ec7bde1cf9714d01f2361a20638e604911510b830a312f07082a1
#   Stored in directory: c:\users\ojgomes\appdata\local\pip\cache\wheels\b3\81\87\9b2b38976b783a8c2baffb72b320d2af59f8da80e6cb6410fd
#   Building wheel for docx2txt (setup.py): started
#   Building wheel for docx2txt (setup.py): finished with status 'done'
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3980 sha256=4e573684e0754e9b17f47aea67097ce59a3bce9276854f8afc4d1e56f90c9900
#   Stored in directory: c:\users\ojgomes\appdata\local\pip\cache\wheels\40\75\01\e6c444034338bde9c7947d3467807f889123465c2371e77418
#   Building wheel for compressed-rtf (setup.py): started
#   Building wheel for compressed-rtf (setup.py): finished with status 'done'
#   Created wheel for compressed-rtf: filename=compressed_rtf-1.0.6-py3-none-any.whl size=6200 sha256=1d94412253c895a55f803fc491cec21006709fe9da3020da577ec40ab8f97e78
#   Stored in directory: c:\users\ojgomes\appdata\local\pip\cache\wheels\e4\67\e4\ba2159853bdd0fe99330aa1e384915108143a5370686ea446f
#   Building wheel for python-pptx (setup.py): started
#   Building wheel for python-pptx (setup.py): finished with status 'done'
#   Created wheel for python-pptx: filename=python_pptx-0.6.21-py3-none-any.whl size=470950 sha256=98fb46f93557ccdd87c218651e4173759980879bafe3b37a709986a35c68706c
#   Stored in directory: c:\users\ojgomes\appdata\local\pip\cache\wheels\0e\4a\ed\9653bc799915f52dce3f04d14946fbd85cce9c3cdedc9cfa71
# Successfully built textract EbookLib docx2txt compressed-rtf python-pptx
# Installing collected packages: tzdata, six, pytz-deprecation-shim, tzlocal, pycryptodome, imapclient, ebcdic, compressed-rtf, chardet, xlrd, SpeechRecognition, python-pptx, pdfminer.six, extract-msg, EbookLib, docx2txt, beautifulsoup4, argcomplete, textract
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 2.0.1
#     Uninstalling xlrd-2.0.1:
#       Successfully uninstalled xlrd-2.0.1
#   Attempting uninstall: pdfminer.six
#     Found existing installation: pdfminer.six 20211012
#     Uninstalling pdfminer.six-20211012:
#       Successfully uninstalled pdfminer.six-20211012
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.10.0
#     Uninstalling beautifulsoup4-4.10.0:
#       Successfully uninstalled beautifulsoup4-4.10.0
# Successfully installed EbookLib-0.17.1 SpeechRecognition-3.8.1 argcomplete-1.10.3 beautifulsoup4-4.8.2 chardet-3.0.4 compressed-rtf-1.0.6 docx2txt-0.8 ebcdic-1.1.1 extract-msg-0.28.7 imapclient-2.1.0 pdfminer.six-20191110 pycryptodome-3.14.1 python-pptx-0.6.21 pytz-deprecation-shim-0.1.0.post0 six-1.12.0 textract-1.6.4 tzdata-2021.5 tzlocal-4.1 xlrd-1.2.0

# %%
from PyPDF4 import PdfFileReader, PdfFileWriter
import pandas as pd
import re
import os
import glob
import tabula
import pytesseract as tess
from PIL import Image
import fitz
import io
import pdfquery
from pdf2image import convert_from_path
import textract

tess.pytesseract.tesseract_cmd = r'C:\Users\ojgomes\AppData\Local\Programs\Tesseract-OCR\tesseract.exe'

# %% [markdown]
# # O código começa aqui

# %%
def pdf_to_text(doc):
    images = convert_from_path(doc)


    texto = tess.image_to_string(images[0])
    #for i in range(len(images)):
   
    # Save pages as images in the pdf
    #images[i].save('page'+ str(i) +'.jpg', 'JPEG')

    #texto = tess.image_to_string(images[i])
    #break
    
    return texto

# %%
#função para extrair imagem do pdf e em seguida retirar texto da imagem 
def extract_text_from_img_doc(doc):
    
    file = fitz.open(doc)
    
    for page_index in range(len(file)):
        #get the page itself
        page = file[page_index]
        image_list = page.getImageList()

        #print number of image this page
        if image_list:
            print(f'[+] Found a total of {len(image_list)} imagesin page {page_index}')
        else:
            print('[!] No image found on page', page_index)
        for image_index, img in enumerate(page.getImageList(), start = 1):
            #get the XREF of the image
            xref = img[0]

            #extract image bytes
            base_image = file.extractImage(xref)
            image_bytes = base_image['image']

            #get the image extension
            image_ext = base_image['ext']

            #load it to PIL
            image = Image.open(io.BytesIO(image_bytes)).convert("RGB")
            
            #save it in local disk
            
            #image.save(open(f'image{page_index+1}_{image_index}.{image_ext}', 'wb'))
    file.close()
    texto = tess.image_to_string(image)
    return texto

# %% [markdown]
# # Procurando apenas por CNPJ

# %%
#ler pasta onde ficam os boletos
file_path = 'boletos/'

#transformando df para uma lista de todos os pdfs da pasta com a bliblioteca glob
df = glob.glob(os.path.join(file_path,'*.pdf'))

df2 = pd.read_excel('Siglas_CNPJs.xlsx')

text = ''

master_list = []

# com df como lista de pdfs itero cada pdf com for abrindo e adicionando as funções que desejo
for i in df:
    
    KeyW3_4 = ''
    
    #leio o pdf com pdf4, informo a quantidade de paginas e em seguida digo que quero o texto do conteudo
    pdf = PdfFileReader(i)
    obtrpage= pdf.getPage(0)
    txt = obtrpage.extractText()
    
    #encontrar CNPJ com regular expression
    KeyW4 = re.findall('\d{2}.\d{3}.\d{3}/\d{4}-\d{2}', txt)
    
    
    #caso o pdf não tenha texto e sim uma imagem não lerá PDF4, assim crie uma condição para ler imagem da msm iteração
    if len(KeyW4) == 0:
        try:
            ban_texto = pdf_to_text(i)
            KeyW4 = re.findall('\d{2}.\d{3}.\d{3}/\d{4}-\d{2}', ban_texto)
            
        except:
            print(f'erro ao ler com função pdf_to_text, boleto:  {i}')
    
    
    
    # em outra condição é tbm para imagems, mas com outra biblioteca para caso a primeira falhar
    if len(KeyW4) == 0:
        try:
            texto = extract_text_from_img_doc(i)
            KeyW4 = re.findall('\d{2}.\d{3}.\d{3}/\d{4}-\d{2}', texto)
                
        except:
            print('nenhuma imagem encontrada')
        
    #caso ainda o PDF não leia outra excelente biblioteca é tabula que ler em formato de tabelas 
    if len(KeyW4) == 0:
        try:
            #ler o pdf, converte de dataframe para lista, da lista converte para string e finalmente obtem o CNPJ com re
            pdft = tabula.read_pdf(i)
            
            pdf_list = pdft[0].iloc[:, 0].values.tolist()
            
            srt_tex = "".join(map(str, pdf_list))
            
            KeyW4 = re.findall('\d{2}.\d{3}.\d{3}/\d{4}-\d{2}', srt_tex)
            
        except:
            pass
    else:
        pass
            
    #removendo duplicidade das listas
    KeyW4 = list(dict.fromkeys(KeyW4))
    
    #removendo o item abaixo
    try:
        KeyW4.remove('42.591.651/0001-43')
    except:
        pass
    
    #KeyW4 = ','.join(KeyW4)
    
    key = [KeyW4]
    
    #este loop varre a lista key e se o item for diferente de 0 então ele aplica o Try 
    for j in key:
        if len(j)!=0:
            try:
                #tenta através de Pandas encontrar o arquivo
                search = df2[df2['CNPJ'].str.contains(j[0], case=False, na=False) | df2['CNPJ 2'].str.contains(j[0], case=False, na=False)]
                sigla = search['SIGLA'].iloc[0] + ' - ' + search['NOVO CC'].iloc[0]
                
                if len(sigla)<=12:
                    print(sigla)
                    os.rename(i, 'boletos\\' + sigla + ' - ' + os.path.basename(i))
                    break

                else:
                    print('o conteudo de sigla não é igual a 12')
            except:
                print(f'erro ao procurar keyword "{j}"')
        else:
            print('erro ')
# Out:
# MFL - B06520
# MFL - B06520
# MFL - B06520
# AFO - B00700
# IBE - B10590
# IBE - B10590
# IBE - B10590
# IBE - B10590
# AFZ - B09700
# IBE - B10590
# IBE - B10590
# IBE - B10590
# IBE - B10590
# IBE - B10590
# PdfReadWarning: Superfluous whitespace found in object header b'1' b'0' [pdf.py:1730]
# PdfReadWarning: Superfluous whitespace found in object header b'2' b'0' [pdf.py:1730]
# PdfReadWarning: Superfluous whitespace found in object header b'3' b'0' [pdf.py:1730]
# PdfReadWarning: Superfluous whitespace found in object header b'23' b'0' [pdf.py:1730]
# ARA - B03310
# ARA - B03310
# ARA - B03310
# IBE - B10590
# IBE - B10590
# FitzDeprecation: 'getImageList' removed from class 'Page' after v1.19 - use 'get_images'. [__init__.py:176]
# FitzDeprecation: 'extractImage' removed from class 'Document' after v1.19 - use 'extract_image'. [__init__.py:176]
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# [+] Found a total of 2 imagesin page 0
# erro
# IBE - B10590
